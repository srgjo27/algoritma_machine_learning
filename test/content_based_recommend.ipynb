# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from tabulate import tabulate

# %%
# Load preprocessed data
preprocessed_product_path = "../data/preprosessing_data/preprocessed_products.csv"
products_df = pd.read_csv(preprocessed_product_path)

# %%
# Define columns to consider for content-based filtering
columns_to_consider = ['category_id', 'subcategory_id', 'skin_type']

# %%
# Combine selected columns into a single string for TF-IDF calculation
products_df['combined_features'] = products_df[columns_to_consider].apply(lambda x: ' '.join(x.astype(str)), axis=1)

# Create TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the combined features to TF-IDF vectors
tfidf_matrix = tfidf_vectorizer.fit_transform(products_df['combined_features'])

# %%
from tabulate import tabulate

# Initialize variables to count TP and FP
TP = 0
FP = 0

# Define threshold for relevance
threshold = 0.5

# Loop through each product as query
for i in range(len(products_df)):
    # Define query vector
    query_vector = tfidf_matrix[i]

    # Calculate cosine similarity with all other products
    cosine_similarities = cosine_similarity(query_vector, tfidf_matrix)

    # Sort the cosine similarities
    similar_indices = cosine_similarities.argsort()[0][-17:-1]  # Get indices of top 16 most similar items

    # Prepare data for recommendation table
    recommendation_table_data = []
    for idx in similar_indices:
        if cosine_similarities[0][idx] > 0:  # Ensuring similarity is greater than 0
            similarity_score = round(cosine_similarities[0][idx], 2)
            product_name = products_df['name'][idx]
            recommendation_table_data.append([similarity_score, product_name])
            if similarity_score >= threshold:
                TP += 1
            else:
                FP += 1

    # Sort recommendation table data based on similarity score
    recommendation_table_data = sorted(recommendation_table_data, key=lambda x: x[0], reverse=True)

    # Prepare data for TF-IDF weights table
    tfidf_table_data = []
    feature_names = tfidf_vectorizer.get_feature_names_out()
    feature_weights = tfidf_matrix[i].toarray()[0]
    for feature, weight in zip(feature_names, feature_weights):
        tfidf_table_data.append([feature, round(weight, 2)])

    # Print recommendations for the current product
    print("\nRecommendations for product:", products_df['name'][i])
    print(tabulate(recommendation_table_data, headers=["Similarity Score", "Product Name"][:16]))
    print("\nTF-IDF Weights:")
    print(tabulate(tfidf_table_data, headers=["Feature", "Weight"]))

# Calculate Precision
precision = (TP / (FP + TP)) * 100
print("\n" + 100 * "=")
print("Precision:", precision)
# Out:
# Recommendations for product: ['zinc', 'refreshing', 'cool', 'anti', 'ketombe']
#   Similarity Score  Product Name
# ------------------  --------------------------------------------------------------------------------
#               1     ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#               1     ['zinc', 'clean', 'active', 'anti', 'ketombe']
#               1     ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
#               1     ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               1     ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               1     ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#               1     ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#               1     ['clear', 'shampoo', 'cool', 'sport', 'menthol', 'men', 'anti', 'ketombe']
#               1     ['head', 'shoulder', 'cool', 'menthol', 'anti', 'dandruff']
#               1     ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               1     ['emeron', 'nutritive', 'shampoo', 'black', 'shine', 'anti', 'ketombe', 'gatal']
#               1     ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.52  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.52  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.52  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.61
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0.79
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['zinc', 'clean', 'active', 'anti', 'ketombe']
#   Similarity Score  Product Name
# ------------------  --------------------------------------------------------------------------------
#               1     ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#               1     ['zinc', 'clean', 'active', 'anti', 'ketombe']
#               1     ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
#               1     ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               1     ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               1     ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#               1     ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#               1     ['clear', 'shampoo', 'cool', 'sport', 'menthol', 'men', 'anti', 'ketombe']
#               1     ['head', 'shoulder', 'cool', 'menthol', 'anti', 'dandruff']
#               1     ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               1     ['emeron', 'nutritive', 'shampoo', 'black', 'shine', 'anti', 'ketombe', 'gatal']
#               1     ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.52  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.52  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.52  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.61
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0.79
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#   Similarity Score  Product Name
# ------------------  --------------------------------------------------------------------------------
#               1     ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#               1     ['zinc', 'clean', 'active', 'anti', 'ketombe']
#               1     ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
#               1     ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               1     ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               1     ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#               1     ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#               1     ['clear', 'shampoo', 'cool', 'sport', 'menthol', 'men', 'anti', 'ketombe']
#               1     ['head', 'shoulder', 'cool', 'menthol', 'anti', 'dandruff']
#               1     ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               1     ['emeron', 'nutritive', 'shampoo', 'black', 'shine', 'anti', 'ketombe', 'gatal']
#               1     ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.52  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.52  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.52  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.61
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0.79
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
#   Similarity Score  Product Name
# ------------------  --------------------------------------------------------------------------------
#               1     ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#               1     ['zinc', 'clean', 'active', 'anti', 'ketombe']
#               1     ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
#               1     ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               1     ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               1     ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#               1     ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#               1     ['clear', 'shampoo', 'cool', 'sport', 'menthol', 'men', 'anti', 'ketombe']
#               1     ['head', 'shoulder', 'cool', 'menthol', 'anti', 'dandruff']
#               1     ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               1     ['emeron', 'nutritive', 'shampoo', 'black', 'shine', 'anti', 'ketombe', 'gatal']
#               1     ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.52  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.52  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.52  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.61
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0.79
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['wardah', 'nutri', 'shine', 'sehat', 'kilau']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------
#               1     ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               1     ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               1     ['wardah', 'nutri', 'shine', 'sehat', 'kilau']
#               1     ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               1     ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               1     ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               1     ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.67  ['makarizo', 'ollive', 'extgract', 'rambut', 'lepek', 'kusam']
#               0.67  ['wardah', 'daily', 'fresh', 'bebas', 'lepek', 'minyak']
#               0.67  ['sunsilk', 'shampoo', 'cocreations', 'black', 'shine', 'hitam', 'anti', 'lepek']
#               0.67  ['head', 'shoulder', 'lemon', 'segar', 'bersih', 'minyak']
#               0.52  ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               0.52  ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['zinc', 'refreshing', 'cool', 'anti', 'ketombe']
#               0.52  ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               0.52  ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.86
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0.51
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['wardah', 'hairfall', 'treatment', 'awat', 'rambut', 'rontok']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------------------------
#               1     ['emeron', 'hairfall', 'control', 'hijau', 'anti', 'rontok']
#               1     ['pantene', 'rambut', 'rontok']
#               1     ['metal', 'fortist', 'panjang', 'rambut']
#               1     ['wardah', 'hairfall', 'treatment', 'awat', 'rambut', 'rontok']
#               1     ['tresemm', 'total', 'salon', 'repair', 'shampoo', 'macadamia', 'oil', 'rambut', 'rusak', 'rontok']
#               1     ['dove', 'peraweatan', 'rambut', 'rontok', 'hijau']
#               1     ['makarizo', 'aloe', 'melon', 'extract', 'rambut', 'rontok']
#               0.52  ['putri', 'hair', 'tonic', 'ginseng', 'rambut', 'rontok']
#               0.52  ['natur', 'natural', 'extract', 'tebal', 'rambut']
#               0.51  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.51  ['pantene', 'rambut', 'rusak']
#               0.51  ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               0.51  ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.51  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               0.51  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.51  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.59
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0.81
# sensitif       0
#
# Recommendations for product: ['wardah', 'daily', 'fresh', 'bebas', 'lepek', 'minyak']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------
#               1     ['sunsilk', 'shampoo', 'cocreations', 'black', 'shine', 'hitam', 'anti', 'lepek']
#               1     ['makarizo', 'ollive', 'extgract', 'rambut', 'lepek', 'kusam']
#               1     ['wardah', 'daily', 'fresh', 'bebas', 'lepek', 'minyak']
#               0.67  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               0.67  ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               0.67  ['wardah', 'nutri', 'shine', 'sehat', 'kilau']
#               0.67  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.67  ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.67  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.67  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.67  ['pantene', 'rambut', 'rusak']
#               0.62  ['pigeon', 'deep', 'cleansing', 'and', 'oil', 'control']
#               0.62  ['pigeon', 'acne', 'care']
#               0.62  ['nivea', 'men', 'acne', 'attack']
#               0.62  ['nivea', 'men', 'bh', 'oil', 'clear']
#               0.62  ['facial', 'wash', 'triple', 'porefection', 'gatsby']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.78
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0
# kombinasi      0
# minyak         0.62
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['metal', 'fortist', 'panjang', 'rambut']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------------------------
#               1     ['emeron', 'hairfall', 'control', 'hijau', 'anti', 'rontok']
#               1     ['pantene', 'rambut', 'rontok']
#               1     ['metal', 'fortist', 'panjang', 'rambut']
#               1     ['wardah', 'hairfall', 'treatment', 'awat', 'rambut', 'rontok']
#               1     ['tresemm', 'total', 'salon', 'repair', 'shampoo', 'macadamia', 'oil', 'rambut', 'rusak', 'rontok']
#               1     ['dove', 'peraweatan', 'rambut', 'rontok', 'hijau']
#               1     ['makarizo', 'aloe', 'melon', 'extract', 'rambut', 'rontok']
#               0.52  ['putri', 'hair', 'tonic', 'ginseng', 'rambut', 'rontok']
#               0.52  ['natur', 'natural', 'extract', 'tebal', 'rambut']
#               0.51  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.51  ['pantene', 'rambut', 'rusak']
#               0.51  ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               0.51  ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.51  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               0.51  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.51  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.59
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0.81
# sensitif       0
#
# Recommendations for product: ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#   Similarity Score  Product Name
# ------------------  --------------------------------------------------------------------------------
#               1     ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#               1     ['zinc', 'clean', 'active', 'anti', 'ketombe']
#               1     ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
#               1     ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               1     ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               1     ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#               1     ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#               1     ['clear', 'shampoo', 'cool', 'sport', 'menthol', 'men', 'anti', 'ketombe']
#               1     ['head', 'shoulder', 'cool', 'menthol', 'anti', 'dandruff']
#               1     ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               1     ['emeron', 'nutritive', 'shampoo', 'black', 'shine', 'anti', 'ketombe', 'gatal']
#               1     ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.52  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.52  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.52  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.61
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0.79
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#   Similarity Score  Product Name
# ------------------  --------------------------------------------------------------------------------
#               1     ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#               1     ['zinc', 'clean', 'active', 'anti', 'ketombe']
#               1     ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
#               1     ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               1     ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               1     ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#               1     ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#               1     ['clear', 'shampoo', 'cool', 'sport', 'menthol', 'men', 'anti', 'ketombe']
#               1     ['head', 'shoulder', 'cool', 'menthol', 'anti', 'dandruff']
#               1     ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               1     ['emeron', 'nutritive', 'shampoo', 'black', 'shine', 'anti', 'ketombe', 'gatal']
#               1     ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.52  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.52  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.52  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.61
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0.79
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#   Similarity Score  Product Name
# ------------------  --------------------------------------------------------------------------------
#               1     ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#               1     ['zinc', 'clean', 'active', 'anti', 'ketombe']
#               1     ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
#               1     ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               1     ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               1     ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#               1     ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#               1     ['clear', 'shampoo', 'cool', 'sport', 'menthol', 'men', 'anti', 'ketombe']
#               1     ['head', 'shoulder', 'cool', 'menthol', 'anti', 'dandruff']
#               1     ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               1     ['emeron', 'nutritive', 'shampoo', 'black', 'shine', 'anti', 'ketombe', 'gatal']
#               1     ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.52  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.52  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.52  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.61
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0.79
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['lifebuoy', 'shampoo', 'merah', 'anti', 'rontok']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------------------------
#               1     ['emeron', 'hairfall', 'control', 'hijau', 'anti', 'rontok']
#               1     ['pantene', 'rambut', 'rontok']
#               1     ['metal', 'fortist', 'panjang', 'rambut']
#               1     ['wardah', 'hairfall', 'treatment', 'awat', 'rambut', 'rontok']
#               1     ['tresemm', 'total', 'salon', 'repair', 'shampoo', 'macadamia', 'oil', 'rambut', 'rusak', 'rontok']
#               1     ['dove', 'peraweatan', 'rambut', 'rontok', 'hijau']
#               1     ['makarizo', 'aloe', 'melon', 'extract', 'rambut', 'rontok']
#               0.52  ['putri', 'hair', 'tonic', 'ginseng', 'rambut', 'rontok']
#               0.52  ['natur', 'natural', 'extract', 'tebal', 'rambut']
#               0.51  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.51  ['pantene', 'rambut', 'rusak']
#               0.51  ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               0.51  ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.51  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               0.51  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.51  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.59
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0.81
# sensitif       0
#
# Recommendations for product: ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#   Similarity Score  Product Name
# ------------------  --------------------------------------------------------------------------------
#               1     ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#               1     ['zinc', 'clean', 'active', 'anti', 'ketombe']
#               1     ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
#               1     ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               1     ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               1     ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#               1     ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#               1     ['clear', 'shampoo', 'cool', 'sport', 'menthol', 'men', 'anti', 'ketombe']
#               1     ['head', 'shoulder', 'cool', 'menthol', 'anti', 'dandruff']
#               1     ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               1     ['emeron', 'nutritive', 'shampoo', 'black', 'shine', 'anti', 'ketombe', 'gatal']
#               1     ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.52  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.52  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.52  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.61
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0.79
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['serasoft', 'shiny', 'black', 'hitam', 'kilau']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------
#               1     ['makarizo', 'kiwi', 'extract', 'rambut', 'proses', 'kimia']
#               0.61  ['wardah', 'nutri', 'shine', 'argan', 'oil', 'grape', 'seed']
#               0.44  ['wardah', 'nutri', 'shine', 'sehat', 'kilau']
#               0.44  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               0.44  ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               0.44  ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.44  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.44  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.44  ['pantene', 'rambut', 'rusak']
#               0.44  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.4   ['wardah', 'daily', 'fresh', 'bebas', 'lepek', 'minyak']
#               0.4   ['makarizo', 'ollive', 'extgract', 'rambut', 'lepek', 'kusam']
#               0.4   ['head', 'shoulder', 'lemon', 'segar', 'bersih', 'minyak']
#               0.4   ['sunsilk', 'shampoo', 'cocreations', 'black', 'shine', 'hitam', 'anti', 'lepek']
#               0.31  ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               0.31  ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.51
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0.86
# kering         0
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['makarizo', 'aloe', 'melon', 'extract', 'rambut', 'rontok']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------------------------
#               1     ['emeron', 'hairfall', 'control', 'hijau', 'anti', 'rontok']
#               1     ['pantene', 'rambut', 'rontok']
#               1     ['metal', 'fortist', 'panjang', 'rambut']
#               1     ['wardah', 'hairfall', 'treatment', 'awat', 'rambut', 'rontok']
#               1     ['tresemm', 'total', 'salon', 'repair', 'shampoo', 'macadamia', 'oil', 'rambut', 'rusak', 'rontok']
#               1     ['dove', 'peraweatan', 'rambut', 'rontok', 'hijau']
#               1     ['makarizo', 'aloe', 'melon', 'extract', 'rambut', 'rontok']
#               0.52  ['putri', 'hair', 'tonic', 'ginseng', 'rambut', 'rontok']
#               0.52  ['natur', 'natural', 'extract', 'tebal', 'rambut']
#               0.51  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.51  ['pantene', 'rambut', 'rusak']
#               0.51  ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               0.51  ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.51  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               0.51  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.51  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.59
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0.81
# sensitif       0
#
# Recommendations for product: ['makarizo', 'ollive', 'extgract', 'rambut', 'lepek', 'kusam']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------
#               1     ['sunsilk', 'shampoo', 'cocreations', 'black', 'shine', 'hitam', 'anti', 'lepek']
#               1     ['makarizo', 'ollive', 'extgract', 'rambut', 'lepek', 'kusam']
#               1     ['wardah', 'daily', 'fresh', 'bebas', 'lepek', 'minyak']
#               0.67  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               0.67  ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               0.67  ['wardah', 'nutri', 'shine', 'sehat', 'kilau']
#               0.67  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.67  ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.67  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.67  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.67  ['pantene', 'rambut', 'rusak']
#               0.62  ['pigeon', 'deep', 'cleansing', 'and', 'oil', 'control']
#               0.62  ['pigeon', 'acne', 'care']
#               0.62  ['nivea', 'men', 'acne', 'attack']
#               0.62  ['nivea', 'men', 'bh', 'oil', 'clear']
#               0.62  ['facial', 'wash', 'triple', 'porefection', 'gatsby']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.78
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0
# kombinasi      0
# minyak         0.62
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------
#               1     ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               1     ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               1     ['wardah', 'nutri', 'shine', 'sehat', 'kilau']
#               1     ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               1     ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               1     ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               1     ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.67  ['makarizo', 'ollive', 'extgract', 'rambut', 'lepek', 'kusam']
#               0.67  ['wardah', 'daily', 'fresh', 'bebas', 'lepek', 'minyak']
#               0.67  ['sunsilk', 'shampoo', 'cocreations', 'black', 'shine', 'hitam', 'anti', 'lepek']
#               0.67  ['head', 'shoulder', 'lemon', 'segar', 'bersih', 'minyak']
#               0.52  ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               0.52  ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['zinc', 'refreshing', 'cool', 'anti', 'ketombe']
#               0.52  ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               0.52  ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.86
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0.51
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['makarizo', 'kiwi', 'extract', 'rambut', 'proses', 'kimia']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------
#               1     ['makarizo', 'kiwi', 'extract', 'rambut', 'proses', 'kimia']
#               0.61  ['wardah', 'nutri', 'shine', 'argan', 'oil', 'grape', 'seed']
#               0.44  ['wardah', 'nutri', 'shine', 'sehat', 'kilau']
#               0.44  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               0.44  ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               0.44  ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.44  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.44  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.44  ['pantene', 'rambut', 'rusak']
#               0.44  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.4   ['wardah', 'daily', 'fresh', 'bebas', 'lepek', 'minyak']
#               0.4   ['makarizo', 'ollive', 'extgract', 'rambut', 'lepek', 'kusam']
#               0.4   ['head', 'shoulder', 'lemon', 'segar', 'bersih', 'minyak']
#               0.4   ['sunsilk', 'shampoo', 'cocreations', 'black', 'shine', 'hitam', 'anti', 'lepek']
#               0.31  ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               0.31  ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.51
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0.86
# kering         0
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#   Similarity Score  Product Name
# ------------------  --------------------------------------------------------------------------------
#               1     ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#               1     ['zinc', 'clean', 'active', 'anti', 'ketombe']
#               1     ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
#               1     ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               1     ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               1     ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#               1     ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#               1     ['clear', 'shampoo', 'cool', 'sport', 'menthol', 'men', 'anti', 'ketombe']
#               1     ['head', 'shoulder', 'cool', 'menthol', 'anti', 'dandruff']
#               1     ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               1     ['emeron', 'nutritive', 'shampoo', 'black', 'shine', 'anti', 'ketombe', 'gatal']
#               1     ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.52  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.52  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.52  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.61
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0.79
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------
#               1     ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               1     ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               1     ['wardah', 'nutri', 'shine', 'sehat', 'kilau']
#               1     ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               1     ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               1     ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               1     ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.67  ['makarizo', 'ollive', 'extgract', 'rambut', 'lepek', 'kusam']
#               0.67  ['wardah', 'daily', 'fresh', 'bebas', 'lepek', 'minyak']
#               0.67  ['sunsilk', 'shampoo', 'cocreations', 'black', 'shine', 'hitam', 'anti', 'lepek']
#               0.67  ['head', 'shoulder', 'lemon', 'segar', 'bersih', 'minyak']
#               0.52  ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               0.52  ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['zinc', 'refreshing', 'cool', 'anti', 'ketombe']
#               0.52  ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               0.52  ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.86
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0.51
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['sunsilk', 'shampoo', 'cocreations', 'black', 'shine', 'hitam', 'anti', 'lepek']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------
#               1     ['sunsilk', 'shampoo', 'cocreations', 'black', 'shine', 'hitam', 'anti', 'lepek']
#               1     ['makarizo', 'ollive', 'extgract', 'rambut', 'lepek', 'kusam']
#               1     ['wardah', 'daily', 'fresh', 'bebas', 'lepek', 'minyak']
#               0.67  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               0.67  ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               0.67  ['wardah', 'nutri', 'shine', 'sehat', 'kilau']
#               0.67  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.67  ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.67  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.67  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.67  ['pantene', 'rambut', 'rusak']
#               0.62  ['pigeon', 'deep', 'cleansing', 'and', 'oil', 'control']
#               0.62  ['pigeon', 'acne', 'care']
#               0.62  ['nivea', 'men', 'acne', 'attack']
#               0.62  ['nivea', 'men', 'bh', 'oil', 'clear']
#               0.62  ['facial', 'wash', 'triple', 'porefection', 'gatsby']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.78
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0
# kombinasi      0
# minyak         0.62
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------
#               1     ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               1     ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               1     ['wardah', 'nutri', 'shine', 'sehat', 'kilau']
#               1     ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               1     ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               1     ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               1     ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.67  ['makarizo', 'ollive', 'extgract', 'rambut', 'lepek', 'kusam']
#               0.67  ['wardah', 'daily', 'fresh', 'bebas', 'lepek', 'minyak']
#               0.67  ['sunsilk', 'shampoo', 'cocreations', 'black', 'shine', 'hitam', 'anti', 'lepek']
#               0.67  ['head', 'shoulder', 'lemon', 'segar', 'bersih', 'minyak']
#               0.52  ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               0.52  ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['zinc', 'refreshing', 'cool', 'anti', 'ketombe']
#               0.52  ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               0.52  ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.86
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0.51
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['tresemm', 'total', 'salon', 'repair', 'shampoo', 'macadamia', 'oil', 'rambut', 'rusak', 'rontok']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------------------------
#               1     ['emeron', 'hairfall', 'control', 'hijau', 'anti', 'rontok']
#               1     ['pantene', 'rambut', 'rontok']
#               1     ['metal', 'fortist', 'panjang', 'rambut']
#               1     ['wardah', 'hairfall', 'treatment', 'awat', 'rambut', 'rontok']
#               1     ['tresemm', 'total', 'salon', 'repair', 'shampoo', 'macadamia', 'oil', 'rambut', 'rusak', 'rontok']
#               1     ['dove', 'peraweatan', 'rambut', 'rontok', 'hijau']
#               1     ['makarizo', 'aloe', 'melon', 'extract', 'rambut', 'rontok']
#               0.52  ['putri', 'hair', 'tonic', 'ginseng', 'rambut', 'rontok']
#               0.52  ['natur', 'natural', 'extract', 'tebal', 'rambut']
#               0.51  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.51  ['pantene', 'rambut', 'rusak']
#               0.51  ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               0.51  ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.51  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               0.51  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.51  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.59
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0.81
# sensitif       0
#
# Recommendations for product: ['emeron', 'nutritive', 'shampoo', 'black', 'shine', 'anti', 'ketombe', 'gatal']
#   Similarity Score  Product Name
# ------------------  --------------------------------------------------------------------------------
#               1     ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#               1     ['zinc', 'clean', 'active', 'anti', 'ketombe']
#               1     ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
#               1     ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               1     ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               1     ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#               1     ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#               1     ['clear', 'shampoo', 'cool', 'sport', 'menthol', 'men', 'anti', 'ketombe']
#               1     ['head', 'shoulder', 'cool', 'menthol', 'anti', 'dandruff']
#               1     ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               1     ['emeron', 'nutritive', 'shampoo', 'black', 'shine', 'anti', 'ketombe', 'gatal']
#               1     ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.52  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.52  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.52  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.61
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0.79
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['emeron', 'hairfall', 'control', 'hijau', 'anti', 'rontok']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------------------------
#               1     ['emeron', 'hairfall', 'control', 'hijau', 'anti', 'rontok']
#               1     ['pantene', 'rambut', 'rontok']
#               1     ['metal', 'fortist', 'panjang', 'rambut']
#               1     ['wardah', 'hairfall', 'treatment', 'awat', 'rambut', 'rontok']
#               1     ['tresemm', 'total', 'salon', 'repair', 'shampoo', 'macadamia', 'oil', 'rambut', 'rusak', 'rontok']
#               1     ['dove', 'peraweatan', 'rambut', 'rontok', 'hijau']
#               1     ['makarizo', 'aloe', 'melon', 'extract', 'rambut', 'rontok']
#               0.52  ['putri', 'hair', 'tonic', 'ginseng', 'rambut', 'rontok']
#               0.52  ['natur', 'natural', 'extract', 'tebal', 'rambut']
#               0.51  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.51  ['pantene', 'rambut', 'rusak']
#               0.51  ['dove', 'awat', 'rambut', 'rusak', 'biru', 'tua']
#               0.51  ['makarizo', 'royal', 'jelly', 'extract', 'rambut', 'kering', 'rusak']
#               0.51  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#               0.51  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.51  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.59
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0.81
# sensitif       0
#
# Recommendations for product: ['clear', 'shampoo', 'cool', 'sport', 'menthol', 'men', 'anti', 'ketombe']
#   Similarity Score  Product Name
# ------------------  --------------------------------------------------------------------------------
#               1     ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#               1     ['zinc', 'clean', 'active', 'anti', 'ketombe']
#               1     ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
#               1     ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#               1     ['serasoft', 'dandruff', 'treatment', 'anti', 'ketombe']
#               1     ['selsun', 'yellow', 'double', 'impcat', 'rambut', 'ketombe']
#               1     ['lifebuoy', 'shampoo', 'biru', 'anti', 'dandruff']
#               1     ['clear', 'shampoo', 'cool', 'sport', 'menthol', 'men', 'anti', 'ketombe']
#               1     ['head', 'shoulder', 'cool', 'menthol', 'anti', 'dandruff']
#               1     ['sunsilk', 'lidah', 'buaya', 'tea', 'tree', 'anti', 'ketombe']
#               1     ['emeron', 'nutritive', 'shampoo', 'black', 'shine', 'anti', 'ketombe', 'gatal']
#               1     ['selsun', 'blue', 'shampoo', 'rambut', 'ketombe']
#               0.52  ['dove', 'awat', 'rambut', 'kilau', 'biru', 'muda']
#               0.52  ['sunsilk', 'nourishing', 'soft', 'smooth', 'rambut', 'lembut']
#               0.52  ['lifebuoy', 'shampoo', 'hijau', 'kuat', 'kilau']
#               0.52  ['head', 'shoulder', 'lembut', 'sutra', 'lembut', 'rambut', 'kering']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0.61
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0.79
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['clear', 'ice', 'cool', 'menthol', 'anti', 'ketombe']
#   Similarity Score  Product Name
# ------------------  --------------------------------------------------------------------------------
#               1     ['zinc', 'active', 'fresh', 'anti', 'ketombe']
#               1     ['zinc', 'clean', 'active', 'anti', 'ketombe']
#               1     ['wardah', 'anti', 'dandruff', 'shampoo', 'anti', 'ketombe']
# ...
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['lovely', 'naturals', 'intense', 'moisturizing']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------------
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'romantic', 'floral']
#                  1  ['citra', 'sakura', 'glow', 'uv']
#                  1  ['citra', 'fresh', 'glow', 'uv', 'gel']
#                  1  ['citra', 'night', 'collagen', 'glow']
#                  1  ['citra', 'nourishing', 'glow', 'uv']
#                  1  ['herborist', 'skin', 'mosturizer', 'aloe', 'vera', 'gel']
#                  1  ['marina', 'natural', 'rich', 'moisturizing', 'avocado', 'olive', 'oil']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'favorable', 'fresh']
#                  1  ['marina', 'natural', 'nourished', 'and', 'healthy', 'sweet', 'almond', 'chia', 'seed']
#                  1  ['aulia', 'body', 'lotion', 'bengkoang']
#                  1  ['aulia', 'body', 'lotion', 'goat', 'milk']
#                  1  ['aulia', 'body', 'lotion', 'musky']
#                  1  ['aulia', 'body', 'lotion', 'milky']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'sweet', 'fruity']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'elegant', 'woody']
#                  1  ['aulia', 'body', 'lotion', 'calming']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0
# 11             0
# 12             0
# 16             0
# 17             0.85
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0.53
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['lovely', 'naturals', 'deep', 'caring']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------------
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'romantic', 'floral']
#                  1  ['citra', 'sakura', 'glow', 'uv']
#                  1  ['citra', 'fresh', 'glow', 'uv', 'gel']
#                  1  ['citra', 'night', 'collagen', 'glow']
#                  1  ['citra', 'nourishing', 'glow', 'uv']
#                  1  ['herborist', 'skin', 'mosturizer', 'aloe', 'vera', 'gel']
#                  1  ['marina', 'natural', 'rich', 'moisturizing', 'avocado', 'olive', 'oil']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'favorable', 'fresh']
#                  1  ['marina', 'natural', 'nourished', 'and', 'healthy', 'sweet', 'almond', 'chia', 'seed']
#                  1  ['aulia', 'body', 'lotion', 'bengkoang']
#                  1  ['aulia', 'body', 'lotion', 'goat', 'milk']
#                  1  ['aulia', 'body', 'lotion', 'musky']
#                  1  ['aulia', 'body', 'lotion', 'milky']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'sweet', 'fruity']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'elegant', 'woody']
#                  1  ['aulia', 'body', 'lotion', 'calming']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0
# 11             0
# 12             0
# 16             0
# 17             0.85
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0.53
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['nivea', 'extra', 'white', 'instant', 'glow']
#   Similarity Score  Product Name
# ------------------  -----------------------------------------------------------------
#               1     ['vaseline', 'aloe', 'soothe']
#               1     ['nivea', 'extra', 'white', 'instant', 'glow']
#               1     ['lovely', 'white', 'uv', 'glow', 'bright', 'red', 'pomegranate']
#               1     ['shinzui', 'hana']
#               0.76  ['herborist', 'facial', 'wash', 'rose']
#               0.76  ['herborist', 'facial', 'wash', 'zaitun']
#               0.76  ['himalaya', 'daily']
#               0.76  ['wardah', 'micellar', 'gentle', 'wash']
#               0.76  ['sari', 'ayu', 'acne', 'care']
#               0.76  ['herborist', 'facial', 'wash', 'tea', 'tree']
#               0.76  ['safi', 'acne', 'clarifying', 'cleanser']
#               0.76  ['pixy', 'dulloff', 'poush']
#               0.76  ['emina', 'bright', 'stuff', 'acne', 'prone', 'skin']
#               0.76  ['wardah', 'clarifying', 'facial', 'foam']
#               0.76  ['glow', 'spa', 'cica']
#               0.76  ['wardah', 'gentle', 'exfoliator', 'scrub']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0
# 11             0
# 12             0
# 16             0
# 17             0.65
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0
# kombinasi      0.76
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['nivea', 'extra', 'white', 'firm', 'smooth']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------------
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'romantic', 'floral']
#                  1  ['citra', 'sakura', 'glow', 'uv']
#                  1  ['citra', 'fresh', 'glow', 'uv', 'gel']
#                  1  ['citra', 'night', 'collagen', 'glow']
#                  1  ['citra', 'nourishing', 'glow', 'uv']
#                  1  ['herborist', 'skin', 'mosturizer', 'aloe', 'vera', 'gel']
#                  1  ['marina', 'natural', 'rich', 'moisturizing', 'avocado', 'olive', 'oil']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'favorable', 'fresh']
#                  1  ['marina', 'natural', 'nourished', 'and', 'healthy', 'sweet', 'almond', 'chia', 'seed']
#                  1  ['aulia', 'body', 'lotion', 'bengkoang']
#                  1  ['aulia', 'body', 'lotion', 'goat', 'milk']
#                  1  ['aulia', 'body', 'lotion', 'musky']
#                  1  ['aulia', 'body', 'lotion', 'milky']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'sweet', 'fruity']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'elegant', 'woody']
#                  1  ['aulia', 'body', 'lotion', 'calming']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0
# 11             0
# 12             0
# 16             0
# 17             0.85
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0.53
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['nivea', 'intensive', 'moisture']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------------
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'romantic', 'floral']
#                  1  ['citra', 'sakura', 'glow', 'uv']
#                  1  ['citra', 'fresh', 'glow', 'uv', 'gel']
#                  1  ['citra', 'night', 'collagen', 'glow']
#                  1  ['citra', 'nourishing', 'glow', 'uv']
#                  1  ['herborist', 'skin', 'mosturizer', 'aloe', 'vera', 'gel']
#                  1  ['marina', 'natural', 'rich', 'moisturizing', 'avocado', 'olive', 'oil']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'favorable', 'fresh']
#                  1  ['marina', 'natural', 'nourished', 'and', 'healthy', 'sweet', 'almond', 'chia', 'seed']
#                  1  ['aulia', 'body', 'lotion', 'bengkoang']
#                  1  ['aulia', 'body', 'lotion', 'goat', 'milk']
#                  1  ['aulia', 'body', 'lotion', 'musky']
#                  1  ['aulia', 'body', 'lotion', 'milky']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'sweet', 'fruity']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'elegant', 'woody']
#                  1  ['aulia', 'body', 'lotion', 'calming']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0
# 11             0
# 12             0
# 16             0
# 17             0.85
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0.53
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['lovely', 'white', 'uv', 'nourish', 'bright', 'bengkoang']
#   Similarity Score  Product Name
# ------------------  ---------------------------------------------------------------------------------------
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'romantic', 'floral']
#                  1  ['citra', 'sakura', 'glow', 'uv']
#                  1  ['citra', 'fresh', 'glow', 'uv', 'gel']
#                  1  ['citra', 'night', 'collagen', 'glow']
#                  1  ['citra', 'nourishing', 'glow', 'uv']
#                  1  ['herborist', 'skin', 'mosturizer', 'aloe', 'vera', 'gel']
#                  1  ['marina', 'natural', 'rich', 'moisturizing', 'avocado', 'olive', 'oil']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'favorable', 'fresh']
#                  1  ['marina', 'natural', 'nourished', 'and', 'healthy', 'sweet', 'almond', 'chia', 'seed']
#                  1  ['aulia', 'body', 'lotion', 'bengkoang']
#                  1  ['aulia', 'body', 'lotion', 'goat', 'milk']
#                  1  ['aulia', 'body', 'lotion', 'musky']
#                  1  ['aulia', 'body', 'lotion', 'milky']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'sweet', 'fruity']
#                  1  ['victoria', 'fragrance', 'body', 'serum', 'elegant', 'woody']
#                  1  ['aulia', 'body', 'lotion', 'calming']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0
# 11             0
# 12             0
# 16             0
# 17             0.85
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0.53
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['lovely', 'white', 'uv', 'glow', 'bright', 'red', 'pomegranate']
#   Similarity Score  Product Name
# ------------------  -----------------------------------------------------------------
#               1     ['vaseline', 'aloe', 'soothe']
#               1     ['nivea', 'extra', 'white', 'instant', 'glow']
#               1     ['lovely', 'white', 'uv', 'glow', 'bright', 'red', 'pomegranate']
#               1     ['shinzui', 'hana']
#               0.76  ['herborist', 'facial', 'wash', 'rose']
#               0.76  ['herborist', 'facial', 'wash', 'zaitun']
#               0.76  ['himalaya', 'daily']
#               0.76  ['wardah', 'micellar', 'gentle', 'wash']
#               0.76  ['sari', 'ayu', 'acne', 'care']
#               0.76  ['herborist', 'facial', 'wash', 'tea', 'tree']
#               0.76  ['safi', 'acne', 'clarifying', 'cleanser']
#               0.76  ['pixy', 'dulloff', 'poush']
#               0.76  ['emina', 'bright', 'stuff', 'acne', 'prone', 'skin']
#               0.76  ['wardah', 'clarifying', 'facial', 'foam']
#               0.76  ['glow', 'spa', 'cica']
#               0.76  ['wardah', 'gentle', 'exfoliator', 'scrub']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0
# 11             0
# 12             0
# 16             0
# 17             0.65
# 18             0
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0
# ketombe        0
# kombinasi      0.76
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['shinzui', 'glow', 'spa', 'ichigo']
#   Similarity Score  Product Name
# ------------------  ------------------------------------------------------------
#               1     ['shinzui', 'glow', 'spa', 'ichigo']
#               1     ['shinzui', 'glow', 'spa', 'cica']
#               0.33  ['safi', 'brightening', 'cleanser', 'mangosteen', 'extract']
#               0.33  ['hanasui', 'body', 'spa', 'blueberry']
#               0.33  ['himalaya', 'moisturizing', 'aloe', 'vera']
#               0.33  ['emina', 'bright', 'stuff']
#               0.33  ['glow', 'spa', 'honey']
#               0.33  ['barrier', 'serum', 'skintific']
#               0.33  ['ponds', 'bright', 'beauty']
#               0.33  ['hanasui', 'flawless', 'glow', '10']
#               0.33  ['lightening', 'serum', 'ampoule', 'wardah']
#               0.33  ['wardah', 'renew', 'you']
#               0.33  ['cpower', 'serum', 'scarlett']
#               0.33  ['air', 'mawar']
#               0.33  ['milk', 'cleanser', 'spirulina']
#               0.33  ['himalaya', 'brightening']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0.94
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0.33
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['shinzui', 'glow', 'spa', 'cica']
#   Similarity Score  Product Name
# ------------------  ------------------------------------------------------------
#               1     ['shinzui', 'glow', 'spa', 'ichigo']
#               1     ['shinzui', 'glow', 'spa', 'cica']
#               0.33  ['safi', 'brightening', 'cleanser', 'mangosteen', 'extract']
#               0.33  ['hanasui', 'body', 'spa', 'blueberry']
#               0.33  ['himalaya', 'moisturizing', 'aloe', 'vera']
#               0.33  ['emina', 'bright', 'stuff']
#               0.33  ['glow', 'spa', 'honey']
#               0.33  ['barrier', 'serum', 'skintific']
#               0.33  ['ponds', 'bright', 'beauty']
#               0.33  ['hanasui', 'flawless', 'glow', '10']
#               0.33  ['lightening', 'serum', 'ampoule', 'wardah']
#               0.33  ['wardah', 'renew', 'you']
#               0.33  ['cpower', 'serum', 'scarlett']
#               0.33  ['air', 'mawar']
#               0.33  ['milk', 'cleanser', 'spirulina']
#               0.33  ['himalaya', 'brightening']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0.94
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0.33
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# Recommendations for product: ['shinzui', 'glow', 'spa', 'honey']
#   Similarity Score  Product Name
# ------------------  ------------------------------------------------------------
#               1     ['shinzui', 'glow', 'spa', 'ichigo']
#               1     ['shinzui', 'glow', 'spa', 'cica']
#               0.33  ['safi', 'brightening', 'cleanser', 'mangosteen', 'extract']
#               0.33  ['hanasui', 'body', 'spa', 'blueberry']
#               0.33  ['himalaya', 'moisturizing', 'aloe', 'vera']
#               0.33  ['emina', 'bright', 'stuff']
#               0.33  ['glow', 'spa', 'honey']
#               0.33  ['barrier', 'serum', 'skintific']
#               0.33  ['ponds', 'bright', 'beauty']
#               0.33  ['hanasui', 'flawless', 'glow', '10']
#               0.33  ['lightening', 'serum', 'ampoule', 'wardah']
#               0.33  ['wardah', 'renew', 'you']
#               0.33  ['cpower', 'serum', 'scarlett']
#               0.33  ['air', 'mawar']
#               0.33  ['milk', 'cleanser', 'spirulina']
#               0.33  ['himalaya', 'brightening']
#
# TF-IDF Weights:
# Feature      Weight
# ---------  --------
# 10             0
# 11             0
# 12             0
# 16             0
# 17             0
# 18             0.94
# 19             0
# 20             0
# 21             0
# cabang         0
# kering         0.33
# ketombe        0
# kombinasi      0
# minyak         0
# normal         0
# rontok         0
# sensitif       0
#
# ====================================================================================================
# Precision: 94.79251423921887
