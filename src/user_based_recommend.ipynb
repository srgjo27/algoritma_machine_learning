# %%
import pandas as pd
import ast
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load preprocessed data
preprocessed_profiles_rating_path = "../data/preprocessed_profiles_rating.csv"
df_profile_ratings = pd.read_csv(preprocessed_profiles_rating_path)

# %%
df_profile_ratings.head()
# Out:
#    id  user_id            name  product_id  rating     gender    age  \
# 0   6        7  Dini Sipahutar       215.0     5.0  Perempuan  18-25
# 1   6        7  Dini Sipahutar        22.0     5.0  Perempuan  18-25
# 2   6        7  Dini Sipahutar       311.0     5.0  Perempuan  18-25
# 3   6        7  Dini Sipahutar       286.0     5.0  Perempuan  18-25
# 4   6        7  Dini Sipahutar        82.0     4.0  Perempuan  18-25
#
#   skin_type_face  hair_issue skin_type_body       allergy_history  \
# 0     ['normal']  ['minyak']     ['normal']  ['tidak ada alergi']
# 1     ['normal']  ['minyak']     ['normal']  ['tidak ada alergi']
# 2     ['normal']  ['minyak']     ['normal']  ['tidak ada alergi']
# 3     ['normal']  ['minyak']     ['normal']  ['tidak ada alergi']
# 4     ['normal']  ['minyak']     ['normal']  ['tidak ada alergi']
#
#                       preferred_products avoided_products  \
# 0  ['cruelty freepewangiminyak mineral']   ['parabensls']
# 1  ['cruelty freepewangiminyak mineral']   ['parabensls']
# 2  ['cruelty freepewangiminyak mineral']   ['parabensls']
# 3  ['cruelty freepewangiminyak mineral']   ['parabensls']
# 4  ['cruelty freepewangiminyak mineral']   ['parabensls']
#
#                               specific_needs
# 0  ['rata warna kulitperlindungan matahari']
# 1  ['rata warna kulitperlindungan matahari']
# 2  ['rata warna kulitperlindungan matahari']
# 3  ['rata warna kulitperlindungan matahari']
# 4  ['rata warna kulitperlindungan matahari']

# %%
df_profile_ratings['product_id'] = df_profile_ratings['product_id'].fillna(0).astype(int)

# %%
df_profile_ratings.head()
# Out:
#    id  user_id            name  product_id  rating     gender    age  \
# 0   6        7  Dini Sipahutar         215     5.0  Perempuan  18-25
# 1   6        7  Dini Sipahutar          22     5.0  Perempuan  18-25
# 2   6        7  Dini Sipahutar         311     5.0  Perempuan  18-25
# 3   6        7  Dini Sipahutar         286     5.0  Perempuan  18-25
# 4   6        7  Dini Sipahutar          82     4.0  Perempuan  18-25
#
#   skin_type_face  hair_issue skin_type_body       allergy_history  \
# 0     ['normal']  ['minyak']     ['normal']  ['tidak ada alergi']
# 1     ['normal']  ['minyak']     ['normal']  ['tidak ada alergi']
# 2     ['normal']  ['minyak']     ['normal']  ['tidak ada alergi']
# 3     ['normal']  ['minyak']     ['normal']  ['tidak ada alergi']
# 4     ['normal']  ['minyak']     ['normal']  ['tidak ada alergi']
#
#                       preferred_products avoided_products  \
# 0  ['cruelty freepewangiminyak mineral']   ['parabensls']
# 1  ['cruelty freepewangiminyak mineral']   ['parabensls']
# 2  ['cruelty freepewangiminyak mineral']   ['parabensls']
# 3  ['cruelty freepewangiminyak mineral']   ['parabensls']
# 4  ['cruelty freepewangiminyak mineral']   ['parabensls']
#
#                               specific_needs
# 0  ['rata warna kulitperlindungan matahari']
# 1  ['rata warna kulitperlindungan matahari']
# 2  ['rata warna kulitperlindungan matahari']
# 3  ['rata warna kulitperlindungan matahari']
# 4  ['rata warna kulitperlindungan matahari']

# %%
# convert skin type, hair issue, skin type body to numeric value (int)
def convert_skin_type_face(skin_type): 
    skin_type_dict = {'normal': 0, 'kering': 1, 'minyak': 2, 'sensitif': 3, 'kombinasi': 4}
    skin_type_list = ast.literal_eval(skin_type)
    return skin_type_dict.get(skin_type_list[0], 0)

def convert_hair_issue(hair_issue): 
    hair_issue_dict = {'normal': 1, 'ketombe': 1, 'kering': 2, 'minyak': 3, 'rontok': 4, 'cabang': 5}
    hair_issue_list = ast.literal_eval(hair_issue)
    return hair_issue_dict.get(hair_issue_list[0], 0)

def convert_skin_type_body(skin_type): 
    skin_type_dict = {'normal': 0, 'kering': 1, 'minyak': 2, 'kombinasi': 3} 
    skin_type_list = ast.literal_eval(skin_type)
    return skin_type_dict.get(skin_type_list[0], 0)

# %%
# functions to the respective columns in the data frame to converting the string values to numeric values based on the provided dictionaries.
df_profile_ratings["skin_type_face"] = df_profile_ratings["skin_type_face"].apply(convert_skin_type_face) 
df_profile_ratings["hair_issue"] = df_profile_ratings["hair_issue"].apply(convert_hair_issue) 
df_profile_ratings["skin_type_body"] = df_profile_ratings["skin_type_body"].apply(convert_skin_type_body)

# %%
# Get the minimum and maximum values for each column
column_min = df_profile_ratings[["skin_type_face", "hair_issue", "skin_type_body"]].min()
column_max = df_profile_ratings[["skin_type_face", "hair_issue", "skin_type_body"]].max()

# Perform min-max scaling
df_profile_ratings[["skin_type_face", "hair_issue", "skin_type_body"]] = (
    df_profile_ratings[["skin_type_face", "hair_issue", "skin_type_body"]] - column_min) / (column_max - column_min)

# Round the values to 3 decimal places
df_profile_ratings[["skin_type_face", "hair_issue", "skin_type_body"]] = df_profile_ratings[["skin_type_face", "hair_issue", "skin_type_body"]].round(3)

# %%
print(df_profile_ratings)
# Out:
#      id  user_id            name  product_id  rating     gender    age  \
# 0     6        7  Dini Sipahutar         215     5.0  Perempuan  18-25
# 1     6        7  Dini Sipahutar          22     5.0  Perempuan  18-25
# 2     6        7  Dini Sipahutar         311     5.0  Perempuan  18-25
# 3     6        7  Dini Sipahutar         286     5.0  Perempuan  18-25
# 4     6        7  Dini Sipahutar          82     4.0  Perempuan  18-25
# ..   ..      ...             ...         ...     ...        ...    ...
# 427  64       67          Wilona         294     5.0  Perempuan  18-38
# 428  64       67          Wilona         315     4.0  Perempuan  18-39
# 429  64       67          Wilona         166     4.0  Perempuan  18-40
# 430  64       67          Wilona         168     5.0  Perempuan  18-41
# 431  64       67          Wilona         262     4.0  Perempuan  18-42
#
#      skin_type_face  hair_issue  skin_type_body             allergy_history  \
# 0              0.00        0.50           0.000        ['tidak ada alergi']
# 1              0.00        0.50           0.000        ['tidak ada alergi']
# 2              0.00        0.50           0.000        ['tidak ada alergi']
# 3              0.00        0.50           0.000        ['tidak ada alergi']
# 4              0.00        0.50           0.000        ['tidak ada alergi']
# ..              ...         ...             ...                         ...
# 427            0.25        0.25           0.333  ['pewangikandungan kimia']
# 428            0.25        0.25           0.333  ['pewangikandungan kimia']
# 429            0.25        0.25           0.333  ['pewangikandungan kimia']
# 430            0.25        0.25           0.333  ['pewangikandungan kimia']
# 431            0.25        0.25           0.333  ['pewangikandungan kimia']
#
#                         preferred_products avoided_products  \
# 0    ['cruelty freepewangiminyak mineral']   ['parabensls']
# 1    ['cruelty freepewangiminyak mineral']   ['parabensls']
# 2    ['cruelty freepewangiminyak mineral']   ['parabensls']
# 3    ['cruelty freepewangiminyak mineral']   ['parabensls']
# 4    ['cruelty freepewangiminyak mineral']   ['parabensls']
# ..                                     ...              ...
# 427                        ['bahan alami']        ['wangi']
# 428                        ['bahan alami']        ['wangi']
# 429                        ['bahan alami']        ['wangi']
# 430                        ['bahan alami']        ['wangi']
# 431                        ['bahan alami']        ['wangi']
#
#                                 specific_needs
# 0    ['rata warna kulitperlindungan matahari']
# 1    ['rata warna kulitperlindungan matahari']
# 2    ['rata warna kulitperlindungan matahari']
# 3    ['rata warna kulitperlindungan matahari']
# 4    ['rata warna kulitperlindungan matahari']
# ..                                         ...
# 427       ['menghidrasiperlindungan matahari']
# 428       ['menghidrasiperlindungan matahari']
# 429       ['menghidrasiperlindungan matahari']
# 430       ['menghidrasiperlindungan matahari']
# 431       ['menghidrasiperlindungan matahari']
#
# [432 rows x 14 columns]

# %%
# Drop rows with NaN values
# df_profile_ratings = df_profile_ratings.dropna(subset=['skin_type_face', 'hair_issue', 'skin_type_body'])

# %%
# Convert user_id to numeric before grouping
df_profile_ratings['user_id'] = df_profile_ratings['user_id'].astype(int)

# Calculate the mean vector for each user
user_vectors = df_profile_ratings.groupby('user_id')[['skin_type_face', 'hair_issue', 'skin_type_body']].mean().round(3)

# Reset the index
user_vectors.reset_index(inplace=True)

# %%
print(user_vectors)
# Out:
#     user_id  skin_type_face  hair_issue  skin_type_body
# 0         7            0.00        0.50           0.000
# 1         8            0.75        0.25           0.333
# 2        11            0.00        0.00           0.667
# 3        12            1.00        0.75           0.000
# 4        13            0.50        0.00           0.000
# 5        14            0.50        0.00           0.000
# 6        15            0.50        0.25           0.000
# 7        16            0.00        0.25           0.000
# 8        17            0.00        0.00           0.000
# 9        18            0.50        0.25           0.000
# 10       19            0.50        0.00           0.000
# 11       20            0.50        0.00           0.333
# 12       21            1.00        0.75           0.000
# 13       22            0.00        0.75           0.000
# 14       23            0.75        0.25           0.000
# 15       24            0.50        0.00           0.333
# 16       25            0.50        0.25           0.333
# 17       26            0.75        0.00           0.000
# 18       28            0.50        0.50           1.000
# 19       29            0.00        0.50           0.000
# 20       30            1.00        0.00           0.333
# 21       32            0.75        0.00           1.000
# 22       33            0.75        0.00           0.333
# 23       34            0.00        1.00           0.333
# 24       35            0.25        0.50           0.000
# 25       36            0.25        0.25           0.333
# 26       37            0.75        0.25           0.000
# 27       38            1.00        0.50           0.000
# 28       39            0.00        0.00           0.000
# 29       40            0.00        0.00           0.000
# 30       41            1.00        0.00           0.000
# 31       42            0.50        0.75           0.000
# 32       43            1.00        0.25           0.333
# 33       44            1.00        0.00           0.000
# 34       45            0.50        0.00           0.667
# 35       46            0.25        0.25           0.000
# 36       47            0.50        0.00           0.333
# 37       48            0.75        0.00           0.000
# 38       49            1.00        0.75           1.000
# 39       50            0.50        0.50           0.000
# 40       51            1.00        0.00           0.333
# 41       52            0.00        0.75           0.000
# 42       54            0.00        0.00           0.000
# 43       55            0.00        0.25           0.000
# 44       56            0.00        0.25           0.333
# 45       57            0.50        0.75           0.000
# 46       58            0.50        0.75           0.000
# 47       59            0.50        0.50           0.000
# 48       60            0.50        1.00           0.667
# 49       61            0.50        0.00           1.000
# 50       62            1.00        0.75           0.000
# 51       63            0.00        0.00           0.000
# 52       64            0.75        0.75           0.333
# 53       65            1.00        0.25           0.333
# 54       66            0.00        0.75           0.333
# 55       67            0.25        0.25           0.333

# %%
# Ubah tipe data user_id ke integer (jika belum integer)
user_vectors['user_id'] = user_vectors['user_id'].astype(int)

# Filter hanya data user_id yang ada dalam file CSV
user_vectors = user_vectors[user_vectors['user_id'].isin(df_profile_ratings['user_id'].unique())]

# Simpan user_id sebelum dihapus dari user_vectors
user_ids = user_vectors['user_id']

# Hapus kolom user_id sebelum menghitung similaritas
user_vectors = user_vectors.drop('user_id', axis=1)

# Hitung similaritas kosinus antara semua pasangan pengguna
user_similarities = cosine_similarity(user_vectors)

# Konversi matriks similaritas ke dataframe pandas
user_similarities = pd.DataFrame(user_similarities, index=user_ids, columns=user_ids)

# %%
print(user_similarities)
# Out:
# user_id        7         8         11        12        13        14        15  \
# user_id
# 7        1.000000  0.291430  0.000000  0.600000  0.000000  0.000000  0.447214
# 8        0.291430  1.000000  0.388184  0.874289  0.874289  0.874289  0.912319
# 11       0.000000  0.388184  1.000000  0.000000  0.000000  0.000000  0.000000
# 12       0.600000  0.874289  0.000000  1.000000  0.800000  0.800000  0.983870
# 13       0.000000  0.874289  0.000000  0.800000  1.000000  1.000000  0.894427
# 14       0.000000  0.874289  0.000000  0.800000  1.000000  1.000000  0.894427
# 15       0.447214  0.912319  0.000000  0.983870  0.894427  0.894427  1.000000
# 16       1.000000  0.291430  0.000000  0.600000  0.000000  0.000000  0.447214
# 17       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 18       0.447214  0.912319  0.000000  0.983870  0.894427  0.894427  1.000000
# 19       0.000000  0.874289  0.000000  0.800000  1.000000  1.000000  0.894427
# 20       0.000000  0.942853  0.554316  0.665845  0.832306  0.832306  0.744437
# 21       0.600000  0.874289  0.000000  1.000000  0.800000  0.800000  0.983870
# 22       1.000000  0.291430  0.000000  0.600000  0.000000  0.000000  0.447214
# 23       0.316228  0.921582  0.000000  0.948683  0.948683  0.948683  0.989949
# 24       0.000000  0.942853  0.554316  0.665845  0.832306  0.832306  0.744437
.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 40       0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 41       0.800000  0.0  0.674639  0.923164  0.000000  0.514738
# 42       0.942990  0.0  0.935556  0.704109  0.760463  0.713813
# 43       0.877006  0.0  0.870586  1.000000  0.335683  0.804757
# 44       0.800000  0.0  0.674639  0.923164  0.000000  0.514738
# 45       0.479846  0.0  0.644329  0.799697  0.324698  0.857347
# 46       0.989949  0.0  0.954084  0.815970  0.646269  0.727949
# 47       0.665845  0.0  0.727546  0.938760  0.224941  0.808476
# 48       0.800000  0.0  0.674639  0.923164  0.000000  0.514738
# 49       0.780869  0.0  0.924648  0.876867  0.681712  0.991030
# 50       0.989949  0.0  0.954084  0.815970  0.646269  0.727949
# 51       0.759023  0.0  0.734720  0.973003  0.128209  0.704992
# 52       0.600000  0.0  0.674639  0.230791  0.913962  0.514738
# 54       0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 55       0.600000  0.0  0.674639  0.230791  0.913962  0.514738
# 56       0.360231  0.0  0.644588  0.384406  0.873251  0.857348
# 57       0.942990  0.0  0.935556  0.704109  0.760463  0.713813
# 58       0.942990  0.0  0.935556  0.704109  0.760463  0.713813
# 59       0.989949  0.0  0.954084  0.815970  0.646269  0.727949
# 60       0.768121  0.0  0.930771  0.689325  0.909939  0.944345
# 61       0.357771  0.0  0.569624  0.687811  0.362958  0.843445
# 62       1.000000  0.0  0.944495  0.877006  0.548377  0.720633
# 63       0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 64       0.944495  0.0  1.000000  0.870586  0.738148  0.899898
# 65       0.877006  0.0  0.870586  1.000000  0.335683  0.804757
# 66       0.548377  0.0  0.738148  0.335683  1.000000  0.748680
# 67       0.720633  0.0  0.899898  0.804757  0.748680  1.000000
#
# [56 rows x 56 columns]

# %%
# Get all unique items
items = df_profile_ratings['product_id'].unique()

# Get all unique user IDs from the preprocessed data
unique_user_ids = df_profile_ratings['user_id'].unique()

# %%
# Initialize a dictionary to store the recommendation values for each user
recommendations = {}

# Iterate over each user ID from the preprocessed data
for user_id in unique_user_ids:
    # Check if the user ID exists in the user_vectors dataframe and has at least one rating
    if user_id in user_vectors.index and user_id in df_profile_ratings['user_id'].values:
        # Calculate the sum of similarity values for the current user
        similarity_sum = user_similarities.loc[user_id].sum()
        
        # Initialize a dictionary to store the prediction values for each item
        predictions = {}
        
        # Check if the user has some similarity with other users
        if similarity_sum > 0:
            # Iterate over each item
            for item in items:
                # Filter the ratings for the current user and item
                ratings = df_profile_ratings[(df_profile_ratings['user_id'] == user_id) & (df_profile_ratings['product_id'] == item)]
                
                # If the user has not rated the item
                if ratings.empty:
                    # Calculate the sum of the ratings weighted by the similarity values
                    rating_sum = (ratings['rating'] * user_similarities.loc[user_id]).sum()
                    # Add the prediction value to the dictionary
                    predictions[item] = rating_sum / similarity_sum
        
        # Add the prediction values for the current user to the recommendations dictionary
        recommendations[user_id] = predictions
    else:
        # If user has no similarity scores or no ratings, assign an empty dictionary
        recommendations[user_id] = {}

# Convert the recommendations dictionary to a pandas dataframe
recommendations_df = pd.DataFrame(recommendations)

# Transpose the dataframe so that user IDs are rows and product IDs are columns
recommendations_df = recommendations_df.T

# Round the values to 3 decimal places
recommendations_df = recommendations_df.round(3)

# %%
# Iterate over each user ID
for user_id in unique_user_ids:
    # Check if the user ID exists in the recommendations dataframe
    if user_id in recommendations_df.index:
        # Look up the user's name in the df_profile_ratings dataframe
        user_name = df_profile_ratings.loc[df_profile_ratings['user_id'] == user_id, 'name'].values[0]

        # Select the row for the specified user
        user_recs = recommendations_df.loc[user_id]

        # Sort the series in descending order and select the top 16 values
        top_recs = user_recs.sort_values(ascending=False).iloc[:10].index.tolist()

        # Print the recommended product IDs and names
        print("Top 10 recommended products for user_id = {} : ({})".format(user_id, user_name))
        print("Product IDs:")
        print(top_recs)
        print("\n")
    else:
        print(f"No recommendations found for user_id = {user_id}")
# Out:
# Top 10 recommended products for user_id = 7 : (Dini Sipahutar)
# Product IDs:
# [58, 33, 57, 211, 13, 305, 50, 116, 149, 12]
#
#
# Top 10 recommended products for user_id = 8 : (Gladys)
# Product IDs:
# [7, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 11 : (Suandika Napitupulu)
# Product IDs:
# [58, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 12 : (Elisa Tambunan)
# Product IDs:
# [58, 83, 48, 313, 259, 137, 73, 232, 45, 65]
#
#
# Top 10 recommended products for user_id = 13 : (Emy Sonia Sinambela)
# Product IDs:
# [24, 75, 48, 313, 259, 137, 73, 232, 45, 65]
#
#
# Top 10 recommended products for user_id = 14 : (Stefhani Kezia)
# Product IDs:
# [58, 273, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 15 : (Josep Phyto Napitupulu)
# Product IDs:
# [58, 34, 259, 137, 73, 232, 45, 65, 75, 187]
#
#
# Top 10 recommended products for user_id = 16 : (Samuel Simanjuntak)
# Product IDs:
# [58, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 17 : (Yoas Sahat Marulitua Hutapea)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 18 : (Boas)
# Product IDs:
# [58, 45, 217, 30, 48, 313, 259, 137, 73, 232]
#
#
# Top 10 recommended products for user_id = 19 : (Jimmi)
# Product IDs:
# [58, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 20 : (Elsie)
# Product IDs:
# [58, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 21 : (Sally Rotua Juliana Panjaitan)
# Product IDs:
# [24, 30, 313, 259, 137, 73, 232, 45, 65, 75]
#
#
# Top 10 recommended products for user_id = 22 : (Natasha)
# Product IDs:
# [58, 217, 48, 313, 259, 137, 73, 232, 45, 65]
#
#
# Top 10 recommended products for user_id = 23 : (Theofil)
# Product IDs:
# [24, 273, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 24 : (Akdes Simamora)
# Product IDs:
# [58, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 25 : (daniel silalahi)
# Product IDs:
# [58, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 26 : (Charlos Purba)
# Product IDs:
# [58, 75, 313, 259, 137, 73, 232, 45, 65, 34]
#
#
# Top 10 recommended products for user_id = 28 : (Yosephine25)
# Product IDs:
# [58, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 29 : (Angelica Theresia Manurung)
# Product IDs:
# [24, 30, 313, 259, 137, 73, 232, 45, 65, 75]
#
#
# Top 10 recommended products for user_id = 30 : (Febri Sihotang)
# Product IDs:
# [58, 217, 48, 313, 259, 137, 73, 232, 45, 65]
#
#
# Top 10 recommended products for user_id = 32 : (Ester anastasia marsada uli Simamora)
# Product IDs:
# [58, 265, 232, 45, 65, 75, 34, 187, 67, 255]
#
#
# Top 10 recommended products for user_id = 33 : (Viranty Napitupulu)
# Product IDs:
# [24, 45, 217, 30, 48, 313, 259, 137, 73, 232]
#
#
# Top 10 recommended products for user_id = 34 : (Silvany Putri Sipahutar)
# Product IDs:
# [24, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 35 : (Juna)
# Product IDs:
# [58, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 36 : (Emely Simanjuntak)
# Product IDs:
# [58, 45, 217, 30, 48, 313, 259, 137, 73, 232]
#
#
# Top 10 recommended products for user_id = 37 : (Elsa Klariza Silalahi)
# Product IDs:
# [58, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 38 : (Anita)
# Product IDs:
# [58, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 39 : (Mesya Angeliqa Hutagalung)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 40 : (Cecilia)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 41 : (aqustin)
# Product IDs:
# [7, 28, 75, 34, 187, 67, 265, 255, 233, 45]
#
#
# Top 10 recommended products for user_id = 42 : (siska)
# Product IDs:
# [58, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 43 : (Mutiara Enjelina)
# Product IDs:
# [58, 45, 217, 30, 48, 313, 259, 137, 73, 232]
#
#
# Top 10 recommended products for user_id = 44 : (Hansel)
# Product IDs:
# [24, 75, 48, 313, 259, 137, 73, 232, 45, 65]
#
#
# Top 10 recommended products for user_id = 45 : (Hans)
# Product IDs:
# [58, 65, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 46 : (Sandi nainggolan)
# Product IDs:
# [58, 273, 30, 48, 313, 259, 137, 73, 232, 45]
#
#
# Top 10 recommended products for user_id = 47 : (Raj Damanik)
# Product IDs:
# [24, 75, 313, 259, 137, 73, 232, 45, 65, 34]
#
#
# Top 10 recommended products for user_id = 48 : (SABAR MARTUA TAMBA)
# Product IDs:
# [58, 273, 313, 259, 137, 73, 232, 45, 65, 75]
#
#
# Top 10 recommended products for user_id = 49 : (Horas Siregar)
# Product IDs:
# [58, 75, 48, 313, 259, 137, 73, 232, 45, 65]
#
#
# Top 10 recommended products for user_id = 50 : (Maryono)
# Product IDs:
# [58, 75, 30, 313, 259, 137, 73, 232, 45, 65]
#
#
# Top 10 recommended products for user_id = 51 : (Putri Napitupulu)
# Product IDs:
# [58, 45, 217, 30, 48, 313, 259, 137, 73, 232]
#
#
# Top 10 recommended products for user_id = 52 : (dedi)
# Product IDs:
# [58, 74, 130, 273, 217, 30, 48, 232, 45, 65]
#
#
# Top 10 recommended products for user_id = 54 : (Merry Tamba)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 55 : (rosa)
# Product IDs:
# [58, 45, 273, 217, 30, 48, 259, 137, 73, 232]
#
#
# Top 10 recommended products for user_id = 56 : (Yoseplin)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 57 : (Anita Munthe)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 58 : (Sulastri)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 59 : (Yosevyn Reginae Sipahutar)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 60 : (Putri Ayu Manurung)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 61 : (Reinaldy Hutapea)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 62 : (Missyolin Eunike Rungguni)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 63 : (Arga)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 64 : (Maria)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 65 : (Sarah Tobing)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 66 : (OLOAN BONAR NAINGGOLAN)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
#
#
# Top 10 recommended products for user_id = 67 : (Wilona)
# Product IDs:
# [58, 24, 300, 7, 315, 294, 134, 42, 123, 167]
